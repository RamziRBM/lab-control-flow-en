# %% [markdown]
# <a href="https://colab.research.google.com/github/RamziRBM/lab-control-flow-en/blob/master/your-code/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Words

# %%
words = ['play', 'filling', 'bar', 'theatre', 'easygoing', 'date', 'lead', 'that', 'story',  'island']

# %% [markdown]
# **Print every word in upper case**

# %%
# your code here
for word in words:
    print(word.upper())
# Out:
# PLAY
# FILLING
# BAR
# THEATRE
# EASYGOING
# DATE
# LEAD
# THAT
# STORY
# ISLAND

# %% [markdown]
# **Create a new list containing only words with 5 or more letters**

# %%
# your code here


new_words=[]
for word in words:
    if(len(word)>=5):
        new_words.append(word)
print(new_words)
# Out:
# ['filling', 'theatre', 'easygoing', 'story', 'island']

# %% [markdown]
# **Print the first word starting with "t"**

# %%
# your code here


for word in words:
    if word.startswith("t"):
        print(word)
        break
# Out:
# theatre

# %% [markdown]
# ## Numbers

# %% [markdown]
# **Create a list containing the square of every number from 1 to 10**

# %%
# your code here


num_squares=[]
for n in range(1,11):
    num_squares.append(n*2)

# %% [markdown]
# **Print a list containing the square of every odd number from 1 to 10**

# %%
# your code here
for num in num_squares:
    if num%4!=0:
        print(num)
# Out:
# 2
# 6
# 10
# 14
# 18

# %% [markdown]
# **Create a list with the squares of all multiples of 8 below 1000**

# %%
# your code here
new_list=[]
for num in range(1,1000):
    if num%8==0:
        new_list.append(num*2)

print(new_list)
# Out:
# [16, 32, 48, 64, 80, 96, 112, 128, 144, 160, 176, 192, 208, 224, 240, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512, 528, 544, 560, 576, 592, 608, 624, 640, 656, 672, 688, 704, 720, 736, 752, 768, 784, 800, 816, 832, 848, 864, 880, 896, 912, 928, 944, 960, 976, 992, 1008, 1024, 1040, 1056, 1072, 1088, 1104, 1120, 1136, 1152, 1168, 1184, 1200, 1216, 1232, 1248, 1264, 1280, 1296, 1312, 1328, 1344, 1360, 1376, 1392, 1408, 1424, 1440, 1456, 1472, 1488, 1504, 1520, 1536, 1552, 1568, 1584, 1600, 1616, 1632, 1648, 1664, 1680, 1696, 1712, 1728, 1744, 1760, 1776, 1792, 1808, 1824, 1840, 1856, 1872, 1888, 1904, 1920, 1936, 1952, 1968, 1984]

# %% [markdown]
# ## People

# %%
people = [
    {
        "name": "Juan",
        "age": 34,
        "n_kids": 2
    },
    {
        "name": "Pepe",
        "age": 27,
        "n_kids": 0
    },
    {
        "name": "Sonia",
        "age": 41,
        "n_kids": 1
    },
    {
        "name": "Lucía",
        "age": 22,
        "n_kids": 2
    },
    {
        "name": "Leo",
        "age": 55,
        "n_kids": 5
    }
]

# %% [markdown]
# **How many people are there?**

# %%
# your code here
print(len(people))
# Out:
# 5

# %% [markdown]
# **How many people have kids**?

# %%
# your code here
parents=0
for person in people:
    if person["n_kids"] != 0:
        parents+=1
print(parents)
# Out:
# 4

# %% [markdown]
# **How many kids do they have in total?**

# %%
# your code here


kids=0
for person in people:
    if person["n_kids"] != 0:
        kids+=person["n_kids"]
print(kids)
# Out:
# 10

# %% [markdown]
# **In a year's time, names ending with "a" will have an extra kid. Create a list of dictionaries with people's info in a year's time**

# %%
# your code here


people_in_year=[]
for person in people:
    if person["name"].endswith("a"):
        person["n_kids"]=person["n_kids"]+1
    people_in_year.append(person)
print(people_in_year)
# Out:
# [{'name': 'Juan', 'age': 34, 'n_kids': 2}, {'name': 'Pepe', 'age': 27, 'n_kids': 0}, {'name': 'Sonia', 'age': 41, 'n_kids': 2}, {'name': 'Lucía', 'age': 22, 'n_kids': 3}, {'name': 'Leo', 'age': 55, 'n_kids': 5}]
